# %%
import pandas as pd

# %%
df = pd.read_csv('reviews-and-ratings.csv')
df.head()
# Out:
#                                                 text  rating
# 0  Парфюм оригинальный. Всё, как в профессиональн...       5
# 1  Мой любимый DKNY. Запах просто шикарный. Спаси...       5
# 2                                                NaN       5
# 3                                                NaN       5
# 4  Запах просто классный, как раз то, что мне нуж...       4

# %%
df.dropna(subset=['text', 'rating'], inplace=True)

# %%
df['rating'] = pd.to_numeric(df['rating'])
average_rating = df['rating'].mean()

print(f"Среднее значение рейтинга: {average_rating:.2f}")
# Out:
# Среднее значение рейтинга: 4.74

# %%
df['word_count'] = df['text'].apply(lambda x: len(str(x).split()))
average_word_count = df['word_count'].mean()
print(f"Среднее количество слов в тексте: {average_word_count:.2f}")
df.drop(columns=['word_count'], inplace=True)
# Out:
# Среднее количество слов в тексте: 8.79

# %%
df['rating'].hist(bins=10, edgecolor='black')
plt.title('Распределение рейтингов')
plt.xlabel('Рейтинг')
plt.ylabel('Частота')
plt.show()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud().generate(' '.join(df['text'].dropna()))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
